# %%
import pickle
import pandas as pd
import numpy as np

# %%
pd.read_pickle('Return_tables.pickle')
# Out:
#                 0                        1                    2           3
# 201901010101   単勝                        1                  140           1
# 201901010101   複勝                  1br3br4        110br110br470     1br2br7
# 201901010101   枠連                    1 - 3                  190           1
# 201901010101   馬連                    1 - 3                  190           1
# 201901010101  ワイド      1 - 3br1 - 4br3 - 4      120br840br1,100   1br12br13
# ...           ...                      ...                  ...         ...
# 201910021212   馬連                   2 - 14                 3530          15
# 201910021212  ワイド  2 - 14br14 - 15br2 - 15  1,310br1,650br4,970  17br23br45
# 201910021212   馬単                   14 → 2                 6020          27
# 201910021212  三連複              2 - 14 - 15                20460          69
# 201910021212  三連単              14 → 2 → 15                86930         291
#
# [27444 rows x 4 columns]

# %%
np.set_printoptions(threshold=np.inf)

# %%
pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',100)
pd.read_pickle('horse_results.pickle')
# Out:
#                     日付    開催  天気     R        レース名  映像  頭数   枠番  馬番   オッズ  \
# 2017105318  2020/12/26  5中山7   晴   9.0  立志賞(1勝クラス) NaN  18  6.0  12   3.5
# 2017105318  2020/08/02  1札幌4   晴   7.0   3歳以上1勝クラス NaN   8  8.0   8   1.5
# 2017105318  2019/08/31  2札幌5   曇  11.0   札幌2歳S(G3) NaN  12  7.0  10   1.8
# 2017105318  2019/07/27  1札幌1   曇   1.0       2歳未勝利 NaN   9  1.0   1   1.4
# 2017105318  2019/06/09  3東京4   曇   5.0        2歳新馬 NaN  11  4.0   4   4.8
# ...                ...   ...  ..   ...         ...  ..  ..  ...  ..   ...
# 2012105474  2015/06/28  3東京8   晴  12.0   3歳以上500万下 NaN  16  4.0   8   4.5
# 2012105474  2015/05/09  2東京5   曇   6.0     3歳500万下 NaN  13  6.0   8   6.3
# 2012105474  2015/04/19  3中山8  小雨   7.0     3歳500万下 NaN  16  2.0   3  27.4
# 2012105474  2015/03/15  2中山6   曇   6.0     3歳500万下 NaN  12  8.0  12  26.1
# 2012105474  2015/01/25  1中山9   晴   4.0        3歳新馬 NaN  16  8.0  15  19.5
#
#              人気  着順    騎手    斤量     距離 馬場 馬場指数     タイム   着差 ﾀｲﾑ指数        通過  \
# ...
